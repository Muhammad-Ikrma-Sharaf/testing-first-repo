# %%
import cv2

# %%
pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (0.19.3)
# Requirement already satisfied: imageio>=2.4.1 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (2.26.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (9.4.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (2021.7.2)
# Requirement already satisfied: scipy>=1.4.1 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (1.10.0)
# Requirement already satisfied: networkx>=2.2 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (2.8.4)
# Requirement already satisfied: packaging>=20.0 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (22.0)
# Requirement already satisfied: numpy>=1.17.0 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (1.23.5)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (1.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
img = cv2.imread("1220.jpg")
cv2.imshow("Image",img)
cv2.waitKey(0)

# %%
import skimage.draw

# %%
pip show scikit-image
# Out:
# Name: scikit-image
# Version: 0.19.3
# Summary: Image processing in Python
# Home-page: https://scikit-image.org
# Author:
# Author-email:
# License: Modified BSD
# Location: /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages
# Requires: imageio, networkx, numpy, packaging, pillow, PyWavelets, scipy, tifffile
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from skimage import draw

# %%
pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (0.19.3)
# Requirement already satisfied: numpy>=1.17.0 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (1.23.5)
# Requirement already satisfied: networkx>=2.2 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (2.8.4)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (2.26.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (1.10.0)
# Requirement already satisfied: packaging>=20.0 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (22.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/MuhammadIkrmaSharaf/anaconda3/lib/python3.10/site-packages (from scikit-image) (1.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import sys
import json
import datetime
import numpy as np
import skimage
from skimage import data, io, filters
import cv2
from mrcnn.visualize import display_instances
import matplotlib.pyplot as plt

# Root directory of the project
ROOT_DIR = "\\Users\\MuhammadIkrmaSharaf\\Desktop\\ks\\maskRcnn"

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn.config import Config
from mrcnn import model as modellib, utils

# Path to trained weights file
COCO_WEIGHTS_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Directory to save logs and model checkpoints, if not provided
# through the command line argument --logs
DEFAULT_LOGS_DIR = os.path.join(ROOT_DIR, "logs")



class CustomConfig(Config):
    """Configuration for training on the custom  dataset.
    Derives from the base Config class and overrides some values.
    """
    # Give the configuration a recognizable name
    NAME = "object"

    # We use a GPU with 12GB memory, which can fit two images.
    # Adjust down if you use a smaller GPU.
    IMAGES_PER_GPU = 2

    # Number of classes (including background)
    NUM_CLASSES = 1 + 2  # Background + car and truck

    # Number of training steps per epoch
    STEPS_PER_EPOCH = 10

    # Skip detections with < 90% confidence
    DETECTION_MIN_CONFIDENCE = 0.4

############################################################
#  Dataset
############################################################
class CustomDataset(utils.Dataset):

    def load_custom(self, dataset_dir, subset):
        """Load a subset of the Dog-Cat dataset.
        dataset_dir: Root directory of the dataset.
        subset: Subset to load: train or val
        """
        # Add classes. We have only one class to add.
        self.add_class("object", 1, "jacket")
        self.add_class("object", 2, "helmet")

        # Train or validation dataset?
        assert subset in ["train", "val"]
        dataset_dir = os.path.join(dataset_dir, subset)

        # We mostly care about the x and y coordinates of each region
        annotations1 = json.load(open('/Users/MuhammadIkrmaSharaf/Desktop/ks/maskRcnn/Dataset/train/train.json'))
        # print(annotations1)
        annotations = list(annotations1.values())  # don't need the dict keys

        # The VIA tool saves images in the JSON even if they don't have any
        # annotations. Skip unannotated images.
        annotations = [a for a in annotations if a['regions']]
        
        # Add images
        for a in annotations:
            # print(a)
            # Get the x, y coordinaets of points of the polygons that make up
            # the outline of each object instance. There are stores in the
            # shape_attributes (see json format above)
            polygons = [r['shape_attributes'] for r in a['regions']] 
            objects = [s['region_attributes']['names'] for s in a['regions']]
            print("objects:",objects)
            name_dict = {"jacket": 1,"helmet": 2}

            # key = tuple(name_dict)
            num_ids = [name_dict[a] for a in objects]
     
            # num_ids = [int(n['Event']) for n in objects]
            # load_mask() needs the image size to convert polygons to masks.
            # Unfortunately, VIA doesn't include it in JSON, so we must read
            # the image. This is only managable since the dataset is tiny.
            print("numids",num_ids)
            image_path = os.path.join(dataset_dir, a['filename'])
            image = skimage.io.imread(image_path)
            height, width = image.shape[:2]

            self.add_image(
                "object",  ## for a single class just add the name here
                image_id=a['filename'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons,
                num_ids=num_ids
                )

def load_mask(self, image_id):
    """Generate instance masks for an image.
    Returns:
    masks: A bool array of shape [height, width, instance count] with
        one mask per instance.
    class_ids: a 1D array of class IDs of the instance masks.
    """
    # If not a Dog-Cat dataset image, delegate to parent class.
    image_info = self.image_info[image_id]
    if image_info["source"] != "object":
        return super(self.__class__, self).load_mask(image_id)

    # Convert polygons to a bitmap mask of shape
    # [height, width, instance_count]
    info = self.image_info[image_id]
    if info["source"] != "object":
        return super(self.__class__, self).load_mask(image_id)
    num_ids = info['num_ids']
    mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                    dtype=np.uint8)
    for i, p in enumerate(info["polygons"]):
        # Get indexes of pixels inside the polygon and set them to 1
        rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
        mask[rr, cc, i] =1

        # Return mask, and array of class IDs of each instance. Since we have
        # one class ID only, we return an array of 1s
        # Map class names to class IDs.
        num_ids = np.array(num_ids, dtype=np.int32)
        return mask, num_ids #np.ones([mask.shape[-1]], dtype=np.int32)

    def image_reference(self, image_id):
        """Return the path of the image."""
        info = self.image_info[image_id]
        if info["source"] == "object":
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)

    def train(model):
        """Train the model."""
        # Training dataset.
        dataset_train = CustomDataset()
        dataset_train.load_custom("/Users/MuhammadIkrmaSharaf/Desktop/ks/maskRcnn/Dataset", "train")
        dataset_train.prepare()

        # Validation dataset
        dataset_val = CustomDataset()
        dataset_val.load_custom("/Users/MuhammadIkrmaSharaf/Desktop/ks/maskRcnn/Dataset", "val")
        dataset_val.prepare()

        # *** This training schedule is an example. Update to your needs ***
        # Since we're using a very small dataset, and starting from
        # COCO trained weights, we don't need to train too long. Also,
        # no need to train all layers, just the heads should do it.
        print("Training network heads")
        model.train(dataset_train, dataset_val,
                    learning_rate=config.LEARNING_RATE,
                    epochs=20,
                    layers='heads')

config = CustomConfig()
model = modellib.MaskRCNN(mode="training", config=config,
                                  model_dir=DEFAULT_LOGS_DIR)

weights_path = COCO_WEIGHTS_PATH
        # Download weights file
if not os.path.exists(weights_path):
    utils.download_trained_weights(weights_path)

model.load_weights(weights_path, by_name=True, exclude=[
            "mrcnn_class_logits", "mrcnn_bbox_fc",
            "mrcnn_bbox", "mrcnn_mask"])

train(model)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 9
#       7 from skimage import data, io, filters
#       8 import cv2
# ----> 9 from mrcnn.visualize import display_instances
#      10 import matplotlib.pyplot as plt
#      12 # Root directory of the project
#
# ModuleNotFoundError: No module named 'mrcnn'

# %%
python setup.py install
# Out:
#   Cell In[24], line 1
#     python setup.py install
#            ^
# SyntaxError: invalid syntax

# %%
conda install -c anaconda scikit-image
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::transformers==4.24.0=py310hecd8cb5_0
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/MuhammadIkrmaSharaf/anaconda3
#
#   added / updated specs:
#     - scikit-image
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.4.26  |       hecd8cb5_0         132 KB  anaconda
#     certifi-2022.6.15          |  py310hecd8cb5_0         157 KB  anaconda
#     openssl-1.1.1u             |       hca72f7f_0         3.4 MB
#     pytorch-1.13.1             |cpu_py310h9e40b02_0        48.3 MB
#     scikit-image-0.19.2        |  py310hc081a56_0        11.5 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:        63.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   pytorch            pkgs/main/osx-64::pytorch-1.13.1-cpu_py310h9e40b02_0
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1t-hca72f7f_0 --> 1.1.1u-hca72f7f_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> anaconda::ca-certificates-2022.4.26-hecd8cb5_0
#   certifi            pkgs/main::certifi-2022.12.7-py310hec~ --> anaconda::certifi-2022.6.15-py310hecd8cb5_0
#   scikit-image       pkgs/main::scikit-image-0.19.3-py310h~ --> anaconda::scikit-image-0.19.2-py310hc081a56_0
#
#
#
# Downloading and Extracting Packages
# pytorch-1.13.1       | 48.3 MB   |                                       |   0%
# scikit-image-0.19.2  | 11.5 MB   |                                       |   0%
#
# certifi-2022.6.15    | 157 KB    |                                       |   0%
#
#
# openssl-1.1.1u       | 3.4 MB    |                                       |   0%
#
#
#
# ca-certificates-2022 | 132 KB    |                                       |   0%
#
#
# openssl-1.1.1u       | 3.4 MB    | 1                                     |   0%
#
#
# openssl-1.1.1u       | 3.4 MB    | ##5                                   |   7%
#
#
# pytorch-1.13.1       | 48.3 MB   |                                       |   0%
#
#
# pytorch-1.13.1       | 48.3 MB   |                                       |   0%
#
#
# openssl-1.1.1u       | 3.4 MB    | ################1                     |  44%
#
# pytorch-1.13.1       | 48.3 MB   | 1                                     |   0%
#
#
# pytorch-1.13.1       | 48.3 MB   | 2                                     |   1%
#
# certifi-2022.6.15    | 157 KB    | ######################6               |  61%
#
#
# openssl-1.1.1u       | 3.4 MB    | ########################1             |  65%
#
# certifi-2022.6.15    | 157 KB    | ##################################### | 100%
#
#
# pytorch-1.13.1       | 48.3 MB   | 2                                     |   1%
#
# certifi-2022.6.15    | 157 KB    | ##################################### | 100%
#
#
# pytorch-1.13.1       | 48.3 MB   | 3                                     |   1%
# scikit-image-0.19.2  | 11.5 MB   |                                       |   0%
#
#
#
# pytorch-1.13.1       | 48.3 MB   | 4                                     |   1%
#
#
#
# ca-certificates-2022 | 132 KB    | ########9                             |  24%
# pytorch-1.13.1       | 48.3 MB   | 5                                     |   1%
#
#
#
# pytorch-1.13.1       | 48.3 MB   | 6                                     |   2%
# scikit-image-0.19.2  | 11.5 MB   | 6                                     |   2%
#
#
#
# ca-certificates-2022 | 132 KB    | ##################################### | 100%
#
#
# pytorch-1.13.1       | 48.3 MB   | 7                                     |   2%
# scikit-image-0.19.2  | 11.5 MB   | 9                                     |   2%
# pytorch-1.13.1       | 48.3 MB   | 9                                     |   3%
# scikit-image-0.19.2  | 11.5 MB   | #4                                    |   4%
# pytorch-1.13.1       | 48.3 MB   | #                                     |   3%
# pytorch-1.13.1       | 48.3 MB   | #1                                    |   3%
# pytorch-1.13.1       | 48.3 MB   | #3                                    |   4%
# pytorch-1.13.1       | 48.3 MB   | #4                                    |   4%
# pytorch-1.13.1       | 48.3 MB   | #5                                    |   4%
# pytorch-1.13.1       | 48.3 MB   | #7                                    |   5%
# pytorch-1.13.1       | 48.3 MB   | #8                                    |   5%
# pytorch-1.13.1       | 48.3 MB   | #9                                    |   5%
# pytorch-1.13.1       | 48.3 MB   | ##1                                   |   6%
# pytorch-1.13.1       | 48.3 MB   | ##3                                   |   6%
# pytorch-1.13.1       | 48.3 MB   | ##4                                   |   7%
# pytorch-1.13.1       | 48.3 MB   | ##5                                   |   7%
# pytorch-1.13.1       | 48.3 MB   | ##7                                   |   7%
# pytorch-1.13.1       | 48.3 MB   | ##8                                   |   8%
# pytorch-1.13.1       | 48.3 MB   | ##9                                   |   8%
# pytorch-1.13.1       | 48.3 MB   | ###                                   |   8%
# pytorch-1.13.1       | 48.3 MB   | ###2                                  |   9%
# pytorch-1.13.1       | 48.3 MB   | ###3                                  |   9%
# pytorch-1.13.1       | 48.3 MB   | ###5                                  |   9%
# pytorch-1.13.1       | 48.3 MB   | ###6                                  |  10%
# scikit-image-0.19.2  | 11.5 MB   | ##############################7       |  83%
# pytorch-1.13.1       | 48.3 MB   | ###7                                  |  10%
# pytorch-1.13.1       | 48.3 MB   | ###9                                  |  11%
# pytorch-1.13.1       | 48.3 MB   | ####                                  |  11%
# pytorch-1.13.1       | 48.3 MB   | ##################6                   |  50%
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
